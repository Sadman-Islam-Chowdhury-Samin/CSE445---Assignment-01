# %%
import math, copy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data= pd.read_csv('AirQualityUCI.csv')
data.head(5)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
columns_to_drop = ['Unnamed: 15', 'Unnamed: 16']
data.drop(columns=columns_to_drop, inplace=True)
data.to_csv('air.csv', index=False)

# %%
data.head(10)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
# 5  3/10/2004  23:00:00     1.2       1197.0      38.0       4.7
# 6  3/11/2004   0:00:00     1.2       1185.0      31.0       3.6
# 7  3/11/2004   1:00:00     1.0       1136.0      31.0       3.3
# 8  3/11/2004   2:00:00     0.9       1094.0      24.0       2.3
# 9  3/11/2004   3:00:00     0.6       1010.0      19.0       1.7
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
# 5          750.0     89.0        1337.0     96.0        1393.0        949.0
# 6          690.0     62.0        1462.0     77.0        1333.0        733.0
# 7          672.0     62.0        1453.0     76.0        1333.0        730.0
# 8          609.0     45.0        1579.0     60.0        1276.0        620.0
# 9          561.0   -200.0        1705.0   -200.0        1235.0        501.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888
# 5  11.2  59.2  0.7848
# 6  11.3  56.8  0.7603
# 7  10.7  60.0  0.7702
# 8  10.7  59.7  0.7648
# 9  10.3  60.2  0.7517

# %%
data.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
numeric_columns = data.select_dtypes(include=['number']).columns
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())
data.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)             0
# PT08.S1(CO)        0
# NMHC(GT)           0
# C6H6(GT)           0
# PT08.S2(NMHC)      0
# NOx(GT)            0
# PT08.S3(NOx)       0
# NO2(GT)            0
# PT08.S4(NO2)       0
# PT08.S5(O3)        0
# T                  0
# RH                 0
# AH                 0
# dtype: int64

# %%
data.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'])

# Convert 'Time' column to datetime
data['Time'] = pd.to_datetime(data['Time'])

# Check the data types of the columns after conversion
data.dtypes
# Out:
# C:\Users\sadman\AppData\Local\Temp\ipykernel_12160\3532489055.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time'])
# Date             datetime64[ns]
# Time             datetime64[ns]
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# dtype: object

# %%
data.isnull()
# Out:
#        Date   Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     False  False   False        False     False     False          False
# 1     False  False   False        False     False     False          False
# 2     False  False   False        False     False     False          False
# 3     False  False   False        False     False     False          False
# 4     False  False   False        False     False     False          False
# ...     ...    ...     ...          ...       ...       ...            ...
# 9466   True   True   False        False     False     False          False
# 9467   True   True   False        False     False     False          False
# 9468   True   True   False        False     False     False          False
# 9469   True   True   False        False     False     False          False
# 9470   True   True   False        False     False     False          False
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T     RH  \
# 0       False         False    False         False        False  False  False
# 1       False         False    False         False        False  False  False
# 2       False         False    False         False        False  False  False
# 3       False         False    False         False        False  False  False
# 4       False         False    False         False        False  False  False
# ...       ...           ...      ...           ...          ...    ...    ...
# 9466    False         False    False         False        False  False  False
# 9467    False         False    False         False        False  False  False
# 9468    False         False    False         False        False  False  False
# 9469    False         False    False         False        False  False  False
# 9470    False         False    False         False        False  False  False
#
#          AH
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9466  False
# 9467  False
# 9468  False
# 9469  False
# 9470  False
#
# [9471 rows x 15 columns]

# %%
data['Date'].fillna(data['Date'].mean(), inplace=True)
data['Time'].fillna(data['Time'].mean(), inplace=True)

# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Convert 'Time' column to datetime
data['Time'] = pd.to_datetime(data['Time'])

# Check the data types of the columns after conversion
data.dtypes
# Out:
# Date             datetime64[ns]
# Time             datetime64[ns]
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
data.isnull()
# Out:
#        Date   Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     False  False   False        False     False     False          False
# 1     False  False   False        False     False     False          False
# 2     False  False   False        False     False     False          False
# 3     False  False   False        False     False     False          False
# 4     False  False   False        False     False     False          False
# ...     ...    ...     ...          ...       ...       ...            ...
# 9466  False  False   False        False     False     False          False
# 9467  False  False   False        False     False     False          False
# 9468  False  False   False        False     False     False          False
# 9469  False  False   False        False     False     False          False
# 9470  False  False   False        False     False     False          False
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T     RH  \
# 0       False         False    False         False        False  False  False
# 1       False         False    False         False        False  False  False
# 2       False         False    False         False        False  False  False
# 3       False         False    False         False        False  False  False
# 4       False         False    False         False        False  False  False
# ...       ...           ...      ...           ...          ...    ...    ...
# 9466    False         False    False         False        False  False  False
# 9467    False         False    False         False        False  False  False
# 9468    False         False    False         False        False  False  False
# 9469    False         False    False         False        False  False  False
# 9470    False         False    False         False        False  False  False
#
#          AH
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9466  False
# 9467  False
# 9468  False
# 9469  False
# 9470  False
#
# [9471 rows x 15 columns]
