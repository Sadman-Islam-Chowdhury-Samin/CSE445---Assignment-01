# %%
import math, copy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

file_path = 'AirQualityUCI.xlsx'

# Load the Excel file into a DataFrame
data = pd.read_excel(file_path)

# Display the DataFrame
data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794

# %%
data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794

# %%
data = pd.DataFrame(data)

x = data.iloc[0:,0:12]
x
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)
# 0           1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1            954.75    103.0       1173.75     92.0       1558.75       972.25
# 2            939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3            948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4            835.50    131.0       1205.00    116.0       1490.00      1110.00
# ...             ...      ...           ...      ...           ...          ...
# 9352        1101.25    471.7        538.50    189.8       1374.25      1728.50
# 9353        1027.00    353.3        603.75    179.2       1263.50      1269.00
# 9354        1062.50    293.0        603.25    174.7       1240.75      1092.00
# 9355         960.50    234.5        701.50    155.7       1041.00       769.75
# 9356        1047.25    265.2        654.00    167.7       1128.50       816.00
#
# [9357 rows x 12 columns]

# %%
x['13'] =1
x
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# 1            954.75    103.0       1173.75     92.0       1558.75
# 2            939.25    131.0       1140.00    114.0       1554.50
# 3            948.25    172.0       1092.00    122.0       1583.75
# 4            835.50    131.0       1205.00    116.0       1490.00
# ...             ...      ...           ...      ...           ...
# 9352        1101.25    471.7        538.50    189.8       1374.25
# 9353        1027.00    353.3        603.75    179.2       1263.50
# 9354        1062.50    293.0        603.25    174.7       1240.75
# 9355         960.50    234.5        701.50    155.7       1041.00
# 9356        1047.25    265.2        654.00    167.7       1128.50
#
#       PT08.S5(O3)  13
# 0         1267.50   1
# 1          972.25   1
# 2         1074.00   1
# 3         1203.25   1
# 4         1110.00   1
# ...           ...  ..
# 9352      1728.50   1
# 9353      1269.00   1
# 9354      1092.00   1
# 9355       769.75   1
# 9356       816.00   1
#
# [9357 rows x 13 columns]

# %%
x = np.array(x)
x
# Out:
# array([[Timestamp('2004-03-10 00:00:00'), datetime.time(18, 0), 2.6, ...,
#         1692.0, 1267.5, 1],
#        [Timestamp('2004-03-10 00:00:00'), datetime.time(19, 0), 2.0, ...,
#         1558.75, 972.25, 1],
#        [Timestamp('2004-03-10 00:00:00'), datetime.time(20, 0), 2.2, ...,
#         1554.5, 1074.0, 1],
#        ...,
#        [Timestamp('2005-04-04 00:00:00'), datetime.time(12, 0), 2.4, ...,
#         1240.75, 1092.0, 1],
#        [Timestamp('2005-04-04 00:00:00'), datetime.time(13, 0), 2.1, ...,
#         1041.0, 769.75, 1],
#        [Timestamp('2005-04-04 00:00:00'), datetime.time(14, 0), 2.2, ...,
#         1128.5, 816.0, 1]], dtype=object)

# %%
y = np.array(data.iloc[0:,12:13])
y
# Out:
# array([[13.5999999 ],
#        [13.29999995],
#        [11.9000001 ],
#        ...,
#        [26.89999962],
#        [28.32499981],
#        [28.50000048]])

# %%
# Cost function
def cost(data, params):
    total_cost = 0
    for i in range(9000):
        total_cost += (1/9000) * ((data[i] * params).sum() - y[i]) ** 2
    return total_cost

# Gradient descent
def gd(data, params, lrate, iter_value):
    for i in range(iter_value):
        slopes = np.zeros(13)  # Initialize slopes as a NumPy array
        for j in range(9000):
            for k in range(13):
                slopes[k] += (1/9000) * ((data[j] * params).sum() - y[j]) * data[j][k]
        params = params - lrate * slopes
        print(cost(data, params))
    return params

# Running gradient descent
params = np.zeros(13)
lrate = 0.001
iter_value = 10000
params = gd(x, params, lrate, iter_value)
print(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 23
#      21 lrate = 0.001
#      22 iter_value = 10000
# ---> 23 params = gd(x, params, lrate, iter_value)
#      24 print(params)
#
# Cell In[19], line 14, in gd(data, params, lrate, iter_value)
#      12 for j in range(9000):
#      13     for k in range(13):
# ---> 14         slopes[k] += (1/9000) * ((data[j] * params).sum() - y[j]) * data[j][k]
#      15 params = params - lrate * slopes
#      16 print(cost(data, params))
#
# TypeError: unsupported operand type(s) for *: 'Timestamp' and 'float'
